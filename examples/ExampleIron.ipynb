# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize']=[10,10]

# %%
from desi_retriever.plotter import plot as  desi_plot
from desi_retriever.iron import get_specs,get_rvspec_models

# %%
# REMEMBER before running this you need to 
# put in $HOME/.desi_http_user
# the desi login password (separated by : ), i.e. login:password

# %% [markdown]
# # Iron

# %% [markdown]
# Fetching spectra by survey/subsurvey, healpix and targetid

# %%
SP = get_specs(survey='sv1',subsurvey='dark',hpx=17683,targetid=39627652591521181)[0]
print (SP)
# Out:
# https://data.desi.lbl.gov/desi//spectro/redux/iron/healpix/sv1/dark/176/17683/coadd-sv1-dark-17683.fits
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ]), 'b_flux': array([17.780697, 17.944153, 20.370407, ..., 19.549887, 19.811869,
#        19.616365], dtype=float32), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ]), 'r_flux': array([19.23231 , 18.990128, 19.925873, ..., 12.459672, 12.192063,
#        12.111976], dtype=float32), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ]), 'z_flux': array([12.905071 , 13.580125 , 12.960547 , ...,  7.764064 ,  7.78188  ,
#         7.7058964], dtype=float32)}

# %% [markdown]
# ## Fetching the corresponding rvspec models

# %%
SPM = get_rvspec_models(survey='sv1', subsurvey='dark', hpx=17683, targetid=39627652591521181)[0]
# Out:
# https://data.desi.lbl.gov/desi/science/mws/redux/iron/rv_output/230211//healpix/sv1/dark/176/17683/rvmod_coadd-sv1-dark-17683.fits

# %%
print(SPM)
# Out:
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ]), 'b_model': array([18.69802435, 18.96630242, 19.37065792, ..., 19.38600735,
#        19.39180617, 19.39063785]), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ]), 'r_model': array([19.41207523, 19.41761566, 19.41830089, ..., 12.64105391,
#        12.63843679, 12.63426815]), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ]), 'z_model': array([12.99261253, 12.99110197, 12.99062722, ...,  7.8632417 ,
#         7.86113587,  7.85918567])}

# %%
desi_plot(SP, model=SPM)

# %% [markdown]
# # Retrieving spectra by GAIA ID

# %%
# Doing this for the first time may take a few seconds
# all the queries after that will be faster
my_sourceid =1384229274732017408;

desi_plot(get_specs(gaia_edr3_source_id=my_sourceid)[0],
               model=
               get_rvspec_models(gaia_edr3_source_id=my_sourceid)[0],
         title='SOURCE_ID=%d'%my_sourceid)
# Out:
# https://data.desi.lbl.gov/desi//spectro/redux/iron/healpix/sv3/backup/98/9835/coadd-sv3-backup-9835.fits
# https://data.desi.lbl.gov/desi/science/mws/redux/iron/rv_output/230211//healpix/sv3/backup/98/9835/rvmod_coadd-sv3-backup-9835.fits
