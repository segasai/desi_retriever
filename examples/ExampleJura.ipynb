# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize']=[10,10]

# %%
from desi_retriever.plotter import plot as  desi_plot
from desi_retriever.jura import get_specs,get_rvspec_models

# %%
# REMEMBER before running this you need to 
# put in $HOME/.desi_http_user
# the desi login password (separated by : ), i.e. login:password

# %% [markdown]
# # Jura

# %% [markdown]
# Fetching spectra by survey/subsurvey, healpix and targetid

# %%
SP = get_specs(survey='sv1',subsurvey='dark',hpx=17683,targetid=39627652591521181)[0]
print (SP)
# Out:
# https://data.desi.lbl.gov/desi//spectro/redux/jura/healpix/sv1/dark/176/17683/coadd-sv1-dark-17683.fits
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ], dtype='>f8'), 'b_flux': array([18.062243, 18.050608, 19.516375, ..., 19.324667, 19.80973 ,
#        19.492794], dtype='>f4'), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ], dtype='>f8'), 'r_flux': array([18.941118 , 19.370348 , 19.300495 , ..., 12.379254 , 12.224014 ,
#        12.3321295], dtype='>f4'), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ], dtype='>f8'), 'z_flux': array([12.832937 , 13.490301 , 12.929832 , ...,  7.7455864,  7.7056603,
#         7.6892214], dtype='>f4')}

# %% [markdown]
# ## Fetching the corresponding rvspec models

# %%
SPM = get_rvspec_models(survey='sv1', subsurvey='dark', hpx=17683, targetid=39627652591521181)[0]
# Out:
# https://data.desi.lbl.gov/desi/science/mws/redux/jura/rv_output/240620//healpix/sv1/dark/176/17683/rvmod_coadd-sv1-dark-17683.fits

# %%
print(SPM)
# Out:
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ], dtype='>f8'), 'b_model': array([18.6679609 , 18.94914389, 19.37031137, ..., 19.36653152,
#        19.37009066, 19.36461273], dtype='>f8'), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ], dtype='>f8'), 'r_model': array([19.43205729, 19.44210329, 19.44172218, ..., 12.63332283,
#        12.63108017, 12.62768221], dtype='>f8'), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ], dtype='>f8'), 'z_model': array([12.9870402 , 12.98714026, 12.98706608, ...,  7.85164158,
#         7.84973067,  7.84794919], dtype='>f8')}

# %%
desi_plot(SP, model=SPM)

# %% [markdown]
# # Retrieving spectra by GAIA ID

# %%
# Doing this for the first time may take a few seconds
# all the queries after that will be faster
my_sourceid =1384229274732017408;

desi_plot(get_specs(gaia_edr3_source_id=my_sourceid)[0],
               model=
               get_rvspec_models(gaia_edr3_source_id=my_sourceid)[0],
         title='SOURCE_ID=%d'%my_sourceid)
# Out:
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/implementations/http.py:420, in HTTPFileSystem._info(self, url, **kwargs)
#     418 try:
#     419     info.update(
# --> 420         await _file_info(
#     421             self.encode_url(url),
#     422             size_policy=policy,
#     423             session=session,
#     424             **self.kwargs,
#     425             **kwargs,
#     426         )
#     427     )
#     428     if info.get("size") is not None:
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/implementations/http.py:833, in _file_info(url, session, size_policy, **kwargs)
#     832 async with r:
# --> 833     r.raise_for_status()
#     835     # TODO:
#     836     #  recognise lack of 'Accept-Ranges',
#     837     #                 or 'Accept-Ranges': 'none' (not 'bytes')
#     838     #  to mean streaming only, no random access => return None
#
# File ~/pyenv310/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1059, in ClientResponse.raise_for_status(self)
#    1058 self.release()
# -> 1059 raise ClientResponseError(
#    1060     self.request_info,
#    1061     self.history,
#    1062     status=self.status,
#    1063     message=self.reason,
#    1064     headers=self.headers,
#    1065 )
#
# ClientResponseError: 404, message='Not Found', url=URL('https://data.desi.lbl.gov/desi/users/koposov/gaiaid_db/gaia-index-jura-coadd.fits')
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 # Doing this for the first time may take a few seconds
#       2 # all the queries after that will be faster
#       3 my_sourceid =1384229274732017408;
# ----> 5 desi_plot(get_specs(gaia_edr3_source_id=my_sourceid)[0],
#       6                model=
#       7                get_rvspec_models(gaia_edr3_source_id=my_sourceid)[0],
#       8          title='SOURCE_ID=%d'%my_sourceid)
#
# File ~/pyenv310/lib/python3.10/site-packages/pylru.py:638, in lrudecorator.__call__.<locals>.wrapper(*args, **kwargs)
#     635 except KeyError:
#     636     pass
# --> 638 value = func(*args, **kwargs)
#     639 self.cache[key] = value
#     640 return value
#
# File ~/pyenv310/lib/python3.10/site-packages/desi_retriever/jura/fetcher.py:232, in get_specs(gaia_edr3_source_id, tileid, night, fiber, hpx, targetid, expid, group_type, dataset, spec_type, survey, subsurvey, spectrograph, mask, ivar)
#     229         spectrograph = fiber // 500
#     231 if gaia_edr3_source_id is not None:
# --> 232     fetch_gaia_index()
#     233     res = si.gaiaIndex.search_id(gaia_edr3_source_id)
#     234     if res is None:
#
# File ~/pyenv310/lib/python3.10/site-packages/desi_retriever/jura/fetcher.py:66, in fetch_gaia_index()
#      60 if si.gaiaIndex is not None:
#      61     return
#      62 D = pyfits.getdata(
#      63     fsspec.open(
#      64         'https://data.desi.lbl.gov/desi/users/koposov/gaiaid_db/gaia-index-jura-coadd.fits',
#      65         'rb',
# ---> 66         auth=aiohttp.BasicAuth(si.DESI_USER, si.DESI_PASSWD)).open())
#      67 si.gaiaIndex = GaiaIndex(D['EDR3_SOURCE_ID'], D['TARGETID'], D['survey'],
#      68                          D['subsurvey'], D['hpx'], D['row'])
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/core.py:135, in OpenFile.open(self)
#     128 def open(self):
#     129     """Materialise this as a real open file without context
#     130
#     131     The OpenFile object should be explicitly closed to avoid enclosed file
#     132     instances persisting. You must, therefore, keep a reference to the OpenFile
#     133     during the life of the file-like it generates.
#     134     """
# --> 135     return self.__enter__()
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/core.py:103, in OpenFile.__enter__(self)
#     100 def __enter__(self):
#     101     mode = self.mode.replace("t", "").replace("b", "") + "b"
# --> 103     f = self.fs.open(self.path, mode=mode)
#     105     self.fobjects = [f]
#     107     if self.compression is not None:
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/spec.py:1295, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1293 else:
#    1294     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1295     f = self._open(
#    1296         path,
#    1297         mode=mode,
#    1298         block_size=block_size,
#    1299         autocommit=ac,
#    1300         cache_options=cache_options,
#    1301         **kwargs,
#    1302     )
#    1303     if compression is not None:
#    1304         from fsspec.compression import compr
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/implementations/http.py:359, in HTTPFileSystem._open(self, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#     357 kw["asynchronous"] = self.asynchronous
#     358 kw.update(kwargs)
# --> 359 size = size or self.info(path, **kwargs)["size"]
#     360 session = sync(self.loop, self.set_session)
#     361 if block_size and size:
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/pyenv310/lib/python3.10/site-packages/fsspec/implementations/http.py:433, in HTTPFileSystem._info(self, url, **kwargs)
#     430     except Exception as exc:
#     431         if policy == "get":
#     432             # If get failed, then raise a FileNotFoundError
# --> 433             raise FileNotFoundError(url) from exc
#     434         logger.debug(str(exc))
#     436 return {"name": url, "size": None, **info, "type": "file"}
#
# FileNotFoundError: https://data.desi.lbl.gov/desi/users/koposov/gaiaid_db/gaia-index-jura-coadd.fits
