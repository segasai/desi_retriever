# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize']=[10,10]

# %%
from desi_retriever.plotter import plot as  desi_plot
from desi_retriever.everest import get_specs,get_rvspec_models

# %%
# REMEMBER before running this you need to 
# put in $HOME/.desi_http_user
# the desi login password (separated by : ), i.e. login:password

# %%
source_id = 3720178836458630144

# %%
# When you run this for the first time it'll take 10-20-30 sec
S=get_specs(gaia_edr3_source_id=source_id)[0]

# %%
print (S)
# Out:
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ]), 'b_flux': array([12.285758, 24.180803, 45.916683, ..., 69.86165 , 51.545418,
#        54.3106  ], dtype=float32), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ]), 'r_flux': array([59.135635, 58.20942 , 57.93425 , ..., 44.005627, 43.907684,
#        41.687527], dtype=float32), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ]), 'z_flux': array([44.747463, 46.892216, 48.812065, ..., 31.438116, 35.371704,
#        34.10215 ], dtype=float32)}

# %% [markdown]
# # simplistic DESI plotter

# %%
desi_plot(S)

# %% [markdown]
# # Fetching RVspecfit models

# %%
M=get_rvspec_models(gaia_edr3_source_id=source_id)[0]

# %%
print(M)
# Out:
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ]), 'b_model': array([32.86590036, 33.46199914, 30.41940233, ..., 55.98087484,
#        56.08488492, 57.30983017]), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ]), 'r_model': array([57.99191862, 56.93772481, 56.71358188, ..., 43.37551606,
#        44.12687652, 44.02552667]), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ]), 'z_model': array([46.21286991, 46.21150383, 46.16838776, ..., 31.25807686,
#        31.19611427, 31.58043858])}

# %%
desi_plot(S, model=M)
