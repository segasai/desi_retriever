# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [10, 10]

# %%
from desi_retriever.plotter import plot as desi_plot
from desi_retriever.matterhorn import get_specs, get_rvspec_models

# %% [markdown]
# REMEMBER before running this you need to
# either
# 1) put in $HOME/.desi_http_user
# the desi login password (separated by : ), i.e. login:password
# or
# 2) Run locally on NERSC

# %% [markdown]
# # Matterhorn

# %% [markdown]
# Fetching spectra by survey/subsurvey, healpix and targetid

# %%
SP = get_specs(survey='sv1',
               program='dark',
                uniqpix=8516,
               targetid=39627652591521181)[0]
print(SP)
# Out:
# https://data.desi.lbl.gov/desi//spectro/redux/matterhorn/spectra/sv1/dark/85/8516/coadd-sv1-dark-8516.fits
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ],
#       shape=(2751,), dtype='>f8'), 'b_flux': array([17.788605, 17.405212, 19.19601 , ..., 19.304094, 19.704725,
#        19.446135], shape=(2751,), dtype='>f4'), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ],
#       shape=(2326,), dtype='>f8'), 'r_flux': array([18.814562, 19.264273, 19.310156, ..., 12.319027, 12.236989,
#        12.289155], shape=(2326,), dtype='>f4'), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ],
#       shape=(2881,), dtype='>f8'), 'z_flux': array([12.841064 , 13.434401 , 12.911826 , ...,  7.7719607,  7.6787014,
#         7.630102 ], shape=(2881,), dtype='>f4')}

# %% [markdown]
# Fetching the variances and fibermaps

# %%
SP = get_specs(survey='sv1',
               program='dark',
               uniqpix=8516,
               targetid=39627652591521181,
               fibermap=True,
               ivar=True)[0]
print(SP)
# Out:
# https://data.desi.lbl.gov/desi//spectro/redux/matterhorn/spectra/sv1/dark/85/8516/coadd-sv1-dark-8516.fits
# {'fibermap': <Row index=22>
#      TARGETID     COADD_FIBERSTATUS     TARGET_RA         TARGET_DEC            DESINAME           PMRA     PMDEC    REF_EPOCH      FA_TARGET      FA_TYPE OBJTYPE    SUBPRIORITY     OBSCONDITIONS RELEASE BRICKNAME BRICKID BRICK_OBJID MORPHTYPE    EBV       FLUX_G    FLUX_R    FLUX_Z   FLUX_W1  FLUX_W2  FLUX_IVAR_G FLUX_IVAR_R FLUX_IVAR_Z FLUX_IVAR_W1 FLUX_IVAR_W2 FIBERFLUX_G FIBERFLUX_R FIBERFLUX_Z FIBERTOTFLUX_G FIBERTOTFLUX_R FIBERTOTFLUX_Z MASKBITS  SERSIC SHAPE_R SHAPE_E1 SHAPE_E2        REF_ID       REF_CAT GAIA_PHOT_G_MEAN_MAG GAIA_PHOT_BP_MEAN_MAG GAIA_PHOT_RP_MEAN_MAG  PARALLAX PHOTSYS PRIORITY_INIT NUMOBS_INIT   SV1_DESI_TARGET   SV1_BGS_TARGET SV1_MWS_TARGET SV1_SCND_TARGET DESI_TARGET BGS_TARGET MWS_TARGET      PLATE_RA         PLATE_DEC      COADD_NUMEXP COADD_EXPTIME COADD_NUMNIGHT COADD_NUMTILE   MEAN_DELTA_X  RMS_DELTA_X  MEAN_DELTA_Y RMS_DELTA_Y  MEAN_PSF_TO_FIBER_SPECFLUX   MEAN_FIBER_RA   STD_FIBER_RA   MEAN_FIBER_DEC   STD_FIBER_DEC    MIN_MJD        MAX_MJD         MEAN_MJD
#       int64             int32            float64           float64               str22           float32   float32    float32         int64         uint8    str3       float64           int32      int16     str8    int32     int32       str4    float32    float32   float32   float32   float32  float32    float32     float32     float32     float32      float32      float32     float32     float32      float32        float32        float32      int16   float32 float32 float32  float32         int64          str2        float32               float32               float32         float32    str1      int64        int64           int64            int64          int64           int64         int64      int64      int64         float64           float64          int16        float32        int16          int16         float32       float32      float32      float32             float32                float64        float32         float64          float32       float64        float64         float64
# ----------------- ----------------- ----------------- ------------------ ---------------------- --------- ---------- --------- ------------------- ------- ------- ------------------ ------------- ------- --------- ------- ----------- --------- ---------- --------- --------- --------- --------- -------- ----------- ----------- ----------- ------------ ------------ ----------- ----------- ----------- -------------- -------------- -------------- -------- ------- ------- -------- -------- ------------------- ------- -------------------- --------------------- --------------------- --------- ------- ------------- ----------- ------------------- -------------- -------------- --------------- ----------- ---------- ---------- ----------------- ------------------ ------------ ------------- -------------- ------------- --------------- ------------ ------------ ------------ -------------------------- ----------------- ------------ ------------------ ------------- -------------- -------------- ---------------
# 39627652591521181                 0 36.24959514018922 -5.614000481996821 DESI J036.2495-05.6140 0.9574808 -2.6028059 2020.9487 2305843017803628544       3     TGT 0.3034680354439797             7    9010  0362m055  298864        3485       PSF 0.02644246 46.976913 60.939743 63.930153 15.106631 8.216161    489.7493   343.34778   173.30675    3.0896175    0.7046385    36.56253    47.42992    49.75738       36.56253       47.42992       49.75738        0     0.0     0.0      0.0      0.0 2488732028166478592      G2            18.089767             18.327694             17.660822 0.4945177       S          1100           1 2305843017803628544              0             33               0           0          0          0 36.24959514018922 -5.614000481996821           35     30258.477              9             2 -0.000114285715 0.0076569295 0.0010285714 0.0072348365                  0.7889999 36.24958981880229  0.109864146 -5.613999754319877    0.10214295 59198.17546592 59251.14239363 59213.679578446, 'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ],
#       shape=(2751,), dtype='>f8'), 'b_flux': array([17.788605, 17.405212, 19.19601 , ..., 19.304094, 19.704725,
#        19.446135], shape=(2751,), dtype='>f4'), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ],
#       shape=(2326,), dtype='>f8'), 'r_flux': array([18.814562, 19.264273, 19.310156, ..., 12.319027, 12.236989,
#        12.289155], shape=(2326,), dtype='>f4'), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ],
#       shape=(2881,), dtype='>f8'), 'z_flux': array([12.841064 , 13.434401 , 12.911826 , ...,  7.7719607,  7.6787014,
#         7.630102 ], shape=(2881,), dtype='>f4'), 'b_ivar': array([ 0.46339142,  0.47459844,  0.5363745 , ..., 11.651749  ,
#        11.154336  , 10.797384  ], shape=(2751,), dtype='>f4'), 'r_ivar': array([ 1.5354311,  1.2947073,  1.4438083, ...,  5.993008 ,  8.009929 ,
#        10.227292 ], shape=(2326,), dtype='>f4'), 'z_ivar': array([23.21732 , 22.784088, 25.703527, ..., 76.335014, 78.87491 ,
#        86.594795], shape=(2881,), dtype='>f4')}

# %% [markdown]
# ## Fetching the corresponding rvspec models

# %%
SPM = get_rvspec_models(survey='sv1',
                        program='dark',
                        uniqpix=8516,
                        targetid=39627652591521181)[0]
# Out:
# https://data.desi.lbl.gov/desi/science/mws/redux/matterhorn/rv_output/260613//sv1/dark/85/8516/rvmod_coadd-sv1-dark-8516.fits

# %%
print(SPM)
# Out:
# {'b_wavelength': array([3600. , 3600.8, 3601.6, ..., 5798.4, 5799.2, 5800. ],
#       shape=(2751,), dtype='>f8'), 'b_model': array([18.960457, 18.770681, 19.114971, ..., 19.25578 , 19.259886,
#        19.2594  ], shape=(2751,), dtype='>f4'), 'r_wavelength': array([5760. , 5760.8, 5761.6, ..., 7618.4, 7619.2, 7620. ],
#       shape=(2326,), dtype='>f8'), 'r_model': array([19.36762 , 19.369896, 19.369219, ..., 12.59126 , 12.589749,
#        12.58689 ], shape=(2326,), dtype='>f4'), 'z_wavelength': array([7520. , 7520.8, 7521.6, ..., 9822.4, 9823.2, 9824. ],
#       shape=(2881,), dtype='>f8'), 'z_model': array([12.930996 , 12.931422 , 12.931294 , ...,  7.8653536,  7.863356 ,
#         7.8616676], shape=(2881,), dtype='>f4')}

# %%
desi_plot(SP, model=SPM)

# %% [markdown]
# # Retrieving spectra by GAIA ID

# %%
# Doing this for the first time may take a few seconds
# all the queries after that will be faster
my_sourceid = 1384229274732017408

desi_plot(get_specs(gaia_edr3_source_id=my_sourceid)[0],
          model=get_rvspec_models(gaia_edr3_source_id=my_sourceid)[0],
          title='SOURCE_ID=%d' % my_sourceid)
# Out:
# Downloading remote parquet file
# Successfully downloaded
# Found 3 spectra, returning 1st one
# https://data.desi.lbl.gov/desi//spectro/redux/matterhorn/spectra/main/bright/262/26219/coadd-main-bright-26219.fits
# Found 3 spectra, returning 1st one
# https://data.desi.lbl.gov/desi/science/mws/redux/matterhorn/rv_output/260613//main/bright/262/26219/rvmod_coadd-main-bright-26219.fits
